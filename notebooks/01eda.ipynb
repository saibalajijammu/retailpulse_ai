# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("../data/raw/Online_retail.xlsx")

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   invoiceno    541909 non-null  object
#  1   stockcode    541909 non-null  object
#  2   description  540455 non-null  object
#  3   quantity     541909 non-null  int64
#  4   invoicedate  541909 non-null  datetime64[ns]
#  5   unitprice    541909 non-null  float64
#  6   customerid   406829 non-null  float64
#  7   country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             quantity                    invoicedate      unitprice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           customerid
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df.isnull().sum()
# Out:
# invoiceno           0
# stockcode           0
# description      1454
# quantity            0
# invoicedate         0
# unitprice           0
# customerid     135080
# country             0
# dtype: int64

# %%
df["quantity"].hist()
# Out:
# <Axes: >

# %% [raw]
# # Observation:
#  Quantity distribution is highly right-skewed with extreme outliers.
#  Negative quantities indicate returned/cancelled transactions.

# %%
df["unitprice"].hist()
# Out:
# <Axes: >

# %% [raw]
# # Observation:
#  Unit price contains invalid negative values and extreme outliers.
#  Data cleaning is required before modeling.

# %%
df["country"].value_counts().head(100)
# Out:
# country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
df['revenue'] = df['quantity'] * df['unitprice']

# %%
df['year'] = df['invoicedate'].dt.year
df['month'] = df['invoicedate'].dt.month
df['day'] = df['invoicedate'].dt.day

# %%
monthly_sales = df.groupby('month')['revenue'].sum()

monthly_sales.plot()
plt.show()

# %% [raw]
# # Observation:
#  Retail sales show strong seasonality.
#  Peak demand occurs during Q4

# %%
corr = df[['quantity', 'unitprice', 'revenue']].corr()

sns.heatmap(corr, annot=True)
plt.show()

# %% [raw]
# # Observation:
#  Revenue is strongly influenced by quantity sold.
#  Unit price has weak negative correlation with revenue,
#  suggesting lower sales volume for expensive products.

# %%
df = df.dropna(subset=["customerid"])

# %%
df = df[df["quantity"] > 0]

# %%
df = df[df["unitprice"] > 0]

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (392692, 12)

# %%
Q1 = df["revenue"].quantile(0.25)
Q3 = df["revenue"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df["revenue"] >= lower) & (df["revenue"] <= upper)]

# %%
df["revenue"].hist()
# Out:
# <Axes: >
